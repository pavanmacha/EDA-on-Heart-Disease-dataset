# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Distrubution of numerical columns :

# %%
df=pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
sns.distplot(df['Age'],kde=False)
# Out:
# C:\Users\M .Pavanteja\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age'>

# %%
sns.distplot(df["RestingBP"],color='blue')
# Out:
# C:\Users\M .Pavanteja\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df["Cholesterol"],color='blue')
# Out:
# C:\Users\M .Pavanteja\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df["MaxHR"],color='blue')
# Out:
# C:\Users\M .Pavanteja\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MaxHR', ylabel='Density'>

# %%
sns.distplot(df["Oldpeak"],color='blue')
# Out:
# C:\Users\M .Pavanteja\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Oldpeak', ylabel='Density'>

# %% [markdown]
# # Columns with categorical data :

# %%
df.groupby('Sex').size()
# Out:
# Sex
# F    193
# M    725
# dtype: int64

# %%
df.groupby('Sex').size().plot(kind='pie',autopct='%.1f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.groupby('ChestPainType').size().plot(kind='pie',autopct='%.1f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.groupby('RestingECG').size().plot(kind='pie',autopct='%.1f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.groupby('HeartDisease').size().plot(kind='pie',autopct='%.1f')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# # Violin plots:

# %%
sns.violinplot(df['Age'])
# Out:
# C:\Users\M .Pavanteja\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.violinplot(df['Sex'],df['HeartDisease'])
# Out:
# C:\Users\M .Pavanteja\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='HeartDisease'>

# %%
sns.violinplot(y=df['Age'],x=df['HeartDisease'])
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(y=df['RestingBP'],x=df['HeartDisease'])
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='RestingBP'>

# %% [markdown]
# # correlation:

# %%
df.corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Jointplot for visualizing the correlation :

# %%
sns.jointplot(x="Oldpeak",y="FastingBS",data=df)

# %%
sns.jointplot(x="MaxHR",y="HeartDisease",data=df)

# %%
sns.jointplot(x="Age",y="MaxHR",data=df)

# %%
sns.jointplot(x="Oldpeak",y="MaxHR",data=df)

# %% [markdown]
# # Pair plot :

# %%
sns.pairplot(df)
